# %%
import sidrapy
import pandas as pd

# %%
tabelas = pd.read_csv('codigos_tabelas.txt',sep='\t', header=None)
tabelas
# Out:
#          1  \
# 0        2
# 1        3
# 2        4
# 3        5
# 4        6
# ...    ...
# 8513  9724
# 8514  9725
# 8515  9726
# 8516  9727
# 8517  9728
#
#      Receita operacional líquida e subvenções das empresas de transporte rodoviário com 20 ou mais pessoas ocupadas, segundo os produtos/serviços prestados
# 0     População ocupada de 15 anos e mais por setor ...
# 1     População ocupada de 15 anos e mais por posiçã...
# 2     Taxa de desemprego aberto - semana por sexo (s...
# 3     Taxa de desemprego aberto - semana por setor d...
# 4     Rendimento médio nominal, do trabalho principa...
# ...                                                 ...
# 8513  Domicílios particulares permanentes ocupados c...
# 8514  Domicílios particulares permanentes ocupados l...
# 8515  Domicílios particulares permanentes ocupados c...
# 8516  Domicílios particulares permanentes ocupados e...
# 8517  Domicílios particulares permanentes ocupados e...
#
# [8518 rows x 2 columns]

# %%
data = sidrapy.get_table(table_code="5917", territorial_level="3", ibge_territorial_code="all", period="last 12")
data
# Out:
#                               NC                    NN  \
# 0     Nível Territorial (Código)     Nível Territorial
# 1                              3  Unidade da Federação
# 2                              3  Unidade da Federação
# 3                              3  Unidade da Federação
# 4                              3  Unidade da Federação
# ...                          ...                   ...
# 1292                           3  Unidade da Federação
# 1293                           3  Unidade da Federação
# 1294                           3  Unidade da Federação
# 1295                           3  Unidade da Federação
# 1296                           3  Unidade da Federação
#
#                               MC                 MN      V  \
# 0     Unidade de Medida (Código)  Unidade de Medida  Valor
# 1                           1572        Mil pessoas    ...
# 2                              2                  %    ...
# 3                              2                  %    ...
# ...
